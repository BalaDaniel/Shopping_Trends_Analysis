# %%
import pandas as pd

# %%
shoppingdf=pd.read_csv('E:/Learning/Edureka/Projects/shopping_trends.csv')
shoppingdf
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# ### Geder wise Sales

# %%
purchases_genderwise=shoppingdf.groupby('Gender')['Purchase Amount (USD)'].sum().reset_index()
purchases_genderwise
# Out:
#    Gender  Purchase Amount (USD)
# 0  Female                  75191
# 1    Male                 157890

# %%
total_purchases=shoppingdf['Purchase Amount (USD)'].sum()
total_purchases
# Out:
# 233081

# %%
purchases_genderwise['Percentage']=(purchases_genderwise['Purchase Amount (USD)']/total_purchases*100).round(2)
purchases_genderwise
# Out:
#    Gender  Purchase Amount (USD)  Percentage
# 0  Female                  75191       32.26
# 1    Male                 157890       67.74

# %%
import matplotlib.pyplot as plt

# %%
fig=plt.figure(figsize=(8,8))
plt.pie(purchases_genderwise['Percentage'],labels=purchases_genderwise['Gender'],autopct='%1.1f%%',startangle=180)
plt.title('Purchase Percentage between male and female')
fig.subplots_adjust(left=1, right=4, top=0.7, bottom=0.3)
plt.show()

# %% [markdown]
# ### Category wise total purchase amount

# %%
purchases_categorywise=shoppingdf.groupby('Category')['Purchase Amount (USD)'].sum().reset_index()
purchases_categorywise
# Out:
#       Category  Purchase Amount (USD)
# 0  Accessories                  74200
# 1     Clothing                 104264
# 2     Footwear                  36093
# 3    Outerwear                  18524

# %%
purchases_categorywise['Percentge']=(purchases_categorywise['Purchase Amount (USD)']/total_purchases*100).round(2)
purchases_categorywise_sort=purchases_categorywise.sort_values(by=['Purchase Amount (USD)'],ascending=False)
purchases_categorywise_sort
# Out:
#       Category  Purchase Amount (USD)  Percentge
# 1     Clothing                 104264      44.73
# 0  Accessories                  74200      31.83
# 2     Footwear                  36093      15.49
# 3    Outerwear                  18524       7.95

# %%
plt.figure(figsize=(6,6))
plt.pie(purchases_categorywise_sort['Percentge'],labels=purchases_categorywise_sort['Category'],autopct='%1.2f%%',startangle=140)
plt.title('Percent of purchases categorywise')
plt.show()

# %% [markdown]
# ### Creating Age_Group column

# %%
bins = [18, 30, 50, 60, 100]
labels = ['18-29', '30-49', '50-59', '60-100']
shoppingdf['Age_group'] = pd.cut(shoppingdf['Age'], bins=bins, labels=labels, right=False)
shoppingdf
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# ### Total Purchased amount by Age_Group

# %%
purchases_by_agegroup=shoppingdf.groupby('Age_group')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False)
purchases_by_agegroup
# Out:
#   Age_group  Purchase Amount (USD)
# 1     30-49                  86766
# 0     18-29                  52905
# 3    60-100                  46894
# 2     50-59                  46516

# %%
plt.figure(figsize=(5,5))
plt.bar(purchases_by_agegroup['Age_group'],purchases_by_agegroup['Purchase Amount (USD)'])
for i, value in enumerate(purchases_by_agegroup['Purchase Amount (USD)']):
    plt.text(i, value, str(value), ha='center', va='bottom')
plt.xlabel('Age_group')
plt.ylabel('Purchase Amount (USD)')
plt.title('Total Purchased amount by Age Group')
plt.show()

# %% [markdown]
# ### top 10 items purchased by male customers

# %%
shoppingdf_male=shoppingdf[shoppingdf['Gender']=='Male']
shoppingdf_male
# Out:
#       Customer ID  Age Gender Item Purchased     Category  \
# 0               1   55   Male         Blouse     Clothing
# 1               2   19   Male        Sweater     Clothing
# 2               3   50   Male          Jeans     Clothing
# 3               4   21   Male        Sandals     Footwear
# 4               5   45   Male         Blouse     Clothing
# ...           ...  ...    ...            ...          ...
# 2647         2648   60   Male          Shoes     Footwear
# 2648         2649   51   Male          Pants     Clothing
# 2649         2650   23   Male         Gloves  Accessories
# 2650         2651   20   Male          Socks     Clothing
# 2651         2652   51   Male       Sneakers     Footwear
#
#       Purchase Amount (USD)        Location Size      Color  Season  \
# 0                        53        Kentucky    L       Gray  Winter
# 1                        64           Maine    L     Maroon  Winter
# ...

# %%
male_purchases=shoppingdf_male.groupby('Item Purchased')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False)
male_purchases.head(10)
# Out:
#    Item Purchased  Purchase Amount (USD)
# 13          Pants                   7154
# 15          Scarf                   6859
# 5           Dress                   6828
# 16          Shirt                   6780
# 12        Jewelry                   6639
# 18         Shorts                   6636
# 23        Sweater                   6539
# 24        T-shirt                   6531
# 4            Coat                   6428
# 1            Belt                   6426

# %% [markdown]
# ### top 10 items purchased by female customers

# %%
shoppingdf_female=shoppingdf[shoppingdf['Gender']=='Female']
shoppingdf_female
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2652         2653   23  Female         Shorts     Clothing
# 2653         2654   67  Female         Blouse     Clothing
# 2654         2655   23  Female           Coat    Outerwear
# 2655         2656   26  Female     Sunglasses  Accessories
# 2656         2657   52  Female         Shorts     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 2652                     20    Maryland    L       Cyan  Summer
# 2653                     36   Wisconsin    L   Lavender    Fall
# ...

# %%
female_purchases=shoppingdf_female.groupby('Item Purchased')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False).head(10)
female_purchases
# Out:
#    Item Purchased  Purchase Amount (USD)
# 2          Blouse                   4016
# 16          Shirt                   3552
# 5           Dress                   3492
# 12        Jewelry                   3371
# 7         Handbag                   3342
# 22     Sunglasses                   3248
# 3           Boots                   3226
# 21          Socks                   3211
# 1            Belt                   3209
# 14        Sandals                   3142

# %%
plt.figure(figsize=(10,6))
plt.bar(female_purchases['Item Purchased'],female_purchases['Purchase Amount (USD)'],color='c')
for i, amount in enumerate(female_purchases['Purchase Amount (USD)']):
    plt.text(i,amount, str(amount), ha='center', va='bottom')
plt.xlabel('Item Purchased')
plt.ylabel('Purchased amount USD')
plt.title('Top 10 purchased items by female customers')
plt.show()

# %% [markdown]
# ### Total Purchased Amount by region

# %%
purchases_region=shoppingdf.groupby('Location')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False)
purchases_region
# Out:
#           Location  Purchase Amount (USD)
# 25         Montana                   5784
# 12        Illinois                   5617
# 4       California                   5605
# 11           Idaho                   5587
# 27          Nevada                   5514
# 0          Alabama                   5261
# 31        New York                   5257
# 33    North Dakota                   5220
# 47   West Virginia                   5174
# 26        Nebraska                   5172
# 30      New Mexico                   5014
# 22       Minnesota                   4977
# 37    Pennsylvania                   4926
# 23     Mississippi                   4883
# 1           Alaska                   4867
# 44         Vermont                   4860
# 17       Louisiana                   4848
# 45        Virginia                   4842
# 3         Arkansas                   4828
# 19        Maryland                   4795
# 41       Tennessee                   4772
# ...

# %% [markdown]
# ### Percentage of regional purchases

# %%
purchases_region['Purchase %']=(purchases_region['Purchase Amount (USD)']/shoppingdf['Purchase Amount (USD)'].sum()*100).round(2)
purchases_region_top10=purchases_region.head(10)
purchases_region_top10
# Out:
#          Location  Purchase Amount (USD)  Purchase %
# 25        Montana                   5784        2.48
# 12       Illinois                   5617        2.41
# 4      California                   5605        2.40
# 11          Idaho                   5587        2.40
# 27         Nevada                   5514        2.37
# 0         Alabama                   5261        2.26
# 31       New York                   5257        2.26
# 33   North Dakota                   5220        2.24
# 47  West Virginia                   5174        2.22
# 26       Nebraska                   5172        2.22

# %%
pip install squarify
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Treemap of top 10 states in higiest purchase amount

# %%
import squarify

# %%
# Create a treemap using squarify
squarify.plot(sizes=purchases_region_top10['Purchase Amount (USD)'], label=purchases_region_top10['Location'], alpha=0.7)

# Remove axis labels and display the plot
plt.figure(figsize=(10,6))
plt.axis('off')
plt.title('Total purchase amount by States')
plt.show()

# %% [markdown]
# ### Distribution of Payment Methods

# %%
payment_method=shoppingdf.groupby('Payment Method')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False)
payment_method
# Out:
#   Payment Method  Purchase Amount (USD)
# 2    Credit Card                  42567
# 5          Venmo                  39991
# 1           Cash                  38833
# 4         PayPal                  37449
# 0  Bank Transfer                  37123
# 3     Debit Card                  37118

# %%
payment_method['Purchased %'] = (payment_method['Purchase Amount (USD)']/shoppingdf['Purchase Amount (USD)'].sum()*100).round(2)
payment_method
# Out:
#   Payment Method  Purchase Amount (USD)  Purchased %
# 2    Credit Card                  42567        18.26
# 5          Venmo                  39991        17.16
# 1           Cash                  38833        16.66
# 4         PayPal                  37449        16.07
# 0  Bank Transfer                  37123        15.93
# 3     Debit Card                  37118        15.92

# %%
plt.figure(figsize=(6,6))
plt.pie(payment_method['Purchased %'],labels=payment_method['Payment Method'],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### Seasonal wise Sales

# %%
seasonal_purchases=shoppingdf.groupby('Season')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False)
seasonal_purchases
# Out:
#    Season  Purchase Amount (USD)
# 0    Fall                  60018
# 1  Spring                  58679
# 3  Winter                  58607
# 2  Summer                  55777

# %% [markdown]
# ### Percent of Seasonal Sales

# %%
seasonal_purchases['Purchase%']=(seasonal_purchases['Purchase Amount (USD)']/shoppingdf['Purchase Amount (USD)'].sum()*100).round(2)
seasonal_purchases
# Out:
#    Season  Purchase Amount (USD)  Purchase%
# 0    Fall                  60018      25.75
# 1  Spring                  58679      25.18
# 3  Winter                  58607      25.14
# 2  Summer                  55777      23.93

# %%
plt.figure(figsize=(6,6))
plt.pie(seasonal_purchases['Purchase%'],labels=seasonal_purchases['Season'],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### Seasonal wise top purchased items

# %%
shoppingdf_fall=shoppingdf[shoppingdf['Season']=='Fall']
shoppingdf_fall
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 6               7   63    Male          Shirt     Clothing
# 10             11   53    Male          Shoes     Footwear
# 24             25   18    Male         Jacket    Outerwear
# 28             29   54    Male        Handbag  Accessories
# 29             30   31    Male          Dress     Clothing
# ...           ...  ...     ...            ...          ...
# 3876         3877   60  Female          Shoes     Footwear
# 3882         3883   35  Female          Pants     Clothing
# 3883         3884   34  Female            Hat  Accessories
# 3884         3885   47  Female        Sandals     Footwear
# 3893         3894   21  Female            Hat  Accessories
#
#       Purchase Amount (USD)        Location Size   Color Season  \
# 6                        85         Montana    M    Gray   Fall
# 10                       34        Arkansas    L  Purple   Fall
# ...

# %% [markdown]
# ### Top Items purchased in Fall season

# %%
shoppingdf_fall_topitems=shoppingdf_fall.groupby('Item Purchased')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False).head(5)
shoppingdf_fall_topitems
# Out:
#    Item Purchased  Purchase Amount (USD)
# 8             Hat                   3224
# 10         Jacket                   3106
# 7         Handbag                   2782
# 14        Sandals                   2741
# 2          Blouse                   2690

# %% [markdown]
# ### Top items purchased in spring season

# %%
shoppingdf_spring=shoppingdf[shoppingdf['Season']=='Spring']
shoppingdf_spring
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# 9              10   57    Male        Handbag  Accessories
# 13             14   65    Male          Dress     Clothing
# ...           ...  ...     ...            ...          ...
# 3889         3890   57  Female          Dress     Clothing
# 3894         3895   66  Female          Skirt     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 2                        73  Massachusetts    S     Maroon  Spring
# 3                        90   Rhode Island    M     Maroon  Spring
# ...

# %%
shoppingdf_spring_topitems=shoppingdf_spring.groupby('Item Purchased')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False).head(5)
shoppingdf_spring_topitems
# Out:
#    Item Purchased  Purchase Amount (USD)
# 23        Sweater                   3145
# 19          Skirt                   2794
# 2          Blouse                   2771
# 18         Shorts                   2704
# 16          Shirt                   2669

# %% [markdown]
# ### Top items purchased in winter season

# %%
shoppingdf_winter=shoppingdf[shoppingdf['Season']=='Winter']
shoppingdf_winter
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 0               1   55    Male         Blouse   Clothing
# 1               2   19    Male        Sweater   Clothing
# 7               8   27    Male         Shorts   Clothing
# 11             12   30    Male         Shorts   Clothing
# 12             13   61    Male           Coat  Outerwear
# ...           ...  ...     ...            ...        ...
# 3879         3880   26  Female          Skirt   Clothing
# 3880         3881   42  Female          Shirt   Clothing
# 3885         3886   49  Female          Socks   Clothing
# 3890         3891   35  Female          Shirt   Clothing
# 3891         3892   36  Female          Dress   Clothing
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 0                        53       Kentucky    L      Gray  Winter
# 1                        64          Maine    L    Maroon  Winter
# 7                        34      Louisiana    L  Charcoal  Winter
# ...

# %%
shoppingdf_winter_topitems=shoppingdf_winter.groupby('Item Purchased')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False).head(5)
shoppingdf_winter_topitems
# Out:
#    Item Purchased  Purchase Amount (USD)
# 16          Shirt                   3102
# 22     Sunglasses                   3085
# 13          Pants                   2999
# 9          Hoodie                   2850
# 12        Jewelry                   2708

# %% [markdown]
# ### Top items purchased in summer season

# %%
shoppingdf_summer=shoppingdf[shoppingdf['Season']=='Summer']
shoppingdf_summer
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 5               6   46    Male       Sneakers     Footwear
# 8               9   26    Male           Coat    Outerwear
# 18             19   52    Male        Sweater     Clothing
# 19             20   66    Male          Pants     Clothing
# 22             23   56    Male          Pants     Clothing
# ...           ...  ...     ...            ...          ...
# 3878         3879   60  Female            Hat  Accessories
# 3886         3887   37  Female        Jewelry  Accessories
# 3892         3893   35  Female        Jewelry  Accessories
# 3895         3896   40  Female         Hoodie     Clothing
# 3898         3899   44  Female          Shoes     Footwear
#
#       Purchase Amount (USD)        Location Size      Color  Season  \
# 5                        20         Wyoming    M      White  Summer
# 8                        97   West Virginia    L     Silver  Summer
# ...

# %%
shoppingdf_summer_topitems=shoppingdf_summer.groupby('Item Purchased')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False).head(5)
shoppingdf_summer_topitems
# Out:
#    Item Purchased  Purchase Amount (USD)
# 12        Jewelry                   3006
# 13          Pants                   2886
# 17          Shoes                   2781
# 0        Backpack                   2780
# 15          Scarf                   2759

# %% [markdown]
# ### Shipping partners by top purchased amount

# %%
shipping_partner=shoppingdf.groupby('Shipping Type')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)',ascending=False)
shipping_partner
# Out:
#     Shipping Type  Purchase Amount (USD)
# 2   Free Shipping                  40777
# 1         Express                  39067
# 5    Store Pickup                  38931
# 4        Standard                  38233
# 0  2-Day Shipping                  38080
# 3    Next Day Air                  37993

# %% [markdown]
# ### Top reviews given by customers

# %%
review_rating=shoppingdf['Review Rating'].value_counts().reset_index().sort_values(by='count',ascending=False)
review_rating
# Out:
#     Review Rating  count
# 0             3.4    182
# 1             4.0    181
# 2             4.6    174
# 3             4.2    171
# 4             2.9    170
# 5             4.9    166
# 6             3.9    163
# 7             3.0    162
# 8             2.6    159
# 9             4.4    158
# 10            3.1    157
# 11            3.7    156
# 12            3.5    156
# 13            2.7    154
# 14            3.3    152
# 15            3.2    152
# 16            3.6    149
# 17            4.7    148
# 18            4.1    148
# 19            4.3    147
# 20            4.8    144
# 21            3.8    142
# 22            4.5    139
# 23            2.8    136
# 24            5.0     68
# 25            2.5     66

# %% [markdown]
# ### No.of customers used promo code

# %%
shoppingdf['Promo Code Used'].value_counts()
# Out:
# Promo Code Used
# No     2223
# Yes    1677
# Name: count, dtype: int64

# %% [markdown]
# ### More frequency of purchases

# %%
shoppingdf['Frequency of Purchases'].value_counts()
# Out:
# Frequency of Purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64
